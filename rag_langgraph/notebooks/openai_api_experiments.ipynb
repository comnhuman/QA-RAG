# %%
from openai import OpenAI

openai_api_key = "EMPTY"
openai_api_base = "http://127.0.0.1:9805/v1"

messages = [
    {"role": "system", "content": "당신은 자동차 정비공입니다."},
    {"role": "user", "content": "가솔린 엔진의 자동차에 경유를 넣었다. 어떻게 되는가?"},
]

client = OpenAI(
    api_key=openai_api_key,
    base_url=openai_api_base,
)

models = client.models.list()
model = models.data[0].id

# Chat Completion API
chat_completion = client.chat.completions.create(
    messages=messages,
    model=model,
)

# %%
print(chat_completion.choices[0].message.content)

# %%
from openai import OpenAI

openai_api_key = "EMPTY"
openai_api_base = "http://127.0.0.1:9805/v1"

messages = [
    {"role": "system", "content": "당신은 AI엔지니어입니다."},
    {"role": "user", "content": "MOE에 대해 설명해줘"},
]

client = OpenAI(
    api_key=openai_api_key,
    base_url=openai_api_base,
)

models = client.models.list()
model = models.data[0].id

# Chat Completion API
chat_completion = client.chat.completions.create(
    messages=messages,
    model=model,
)

# %%
print(chat_completion.choices[0].message.content)

# %%
print(chat_completion.choices[0].message.content)

# %%
print(chat_completion.choices[0].message.content)

# %%
from openai import OpenAI

openai_api_key = "EMPTY"
openai_api_base = "http://127.0.0.1:9805/v1"

messages = [
    {"role": "system", "content": "당신은 자동차 정비공입니다."},
    {"role": "user", "content": "가솔린 엔진의 자동차에 경유를 넣었다. 어떻게 되는가?"},
]

client = OpenAI(
    api_key=openai_api_key,
    base_url=openai_api_base,
)

models = client.models.list()
model = models.data[0].id

# Chat Completion API
chat_completion = client.chat.completions.create(
    messages=messages,
    model=model,
)

# %%
print(chat_completion.choices[0].message.content)
